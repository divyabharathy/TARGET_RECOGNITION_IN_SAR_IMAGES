# %%
# !git clone  https://github.com/AntonMu/TrainYourOwnYOLO.git
# Out:
# Cloning into 'TrainYourOwnYOLO'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 2266 (delta 1), reused 2 (delta 0), pack-reused 2259
# Receiving objects: 100% (2266/2266), 142.02 MiB | 32.85 MiB/s, done.
# Resolving deltas: 100% (741/741), done.

# %%
# %cd TrainYourOwnYOLO/Data/Source_Images/
# Out:
# /content/TrainYourOwnYOLO/Data/Source_Images

# %% [markdown]
# remove all 3 folders Training,testing,results

# %%
# !rm -rf Training_Images

# %%
# !rm -rf Test_Images

# %%
# !rm -rf Test_Image_Detection_Results

# %% [markdown]
# click folder symbol on your left
#
# three icons,click the folder symbol
# click Trainyourownyolo
# under that go to data-> sourceimages->
# right click source images
# add 3 new folders
#
# Training_Images
# Test_Images
# Test_Image_Detection_Results
#
# under training_images
# create a folder vott-csv-export
#
# under that vott-csv-export
# upload labeled images and csv file
#
# csv file name should be Annotations-export   no change in name of this excel file
#
# then under test images upload ur testing images

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %% [markdown]
# Change directory to Trainyolo and move to 1-image-annotation

# %%
# %cd 1_Image_Annotation/
# Out:
# /content/TrainYourOwnYOLO/1_Image_Annotation

# %%
# !python Convert_to_YOLO_format.py

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 2_Training/
# Out:
# /content/TrainYourOwnYOLO/2_Training

# %%
# !python Download_and_Convert_YOLO_weights.py
# Out:
#  99% (2479879 of 2480070) |############## | Elapsed Time: 0:44:58 ETA:   0:00:00Using TensorFlow backend.
# 2020-05-06 13:47:43.231083: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# 2020-05-06 13:47:45.109908: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-06 13:47:45.164186: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-06 13:47:45.165037: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# ...

# %% [markdown]
# when u run the below code u will get error at first stating that control_flow_ops is missing
#
# now on your left under upload
#
# u have a folder symbol with 2 dots click that
#
# click usr->local->lib->python 3.6->dist-packages->keras->backend->
#
# open tensorflow_backend.py
#
# add
# from tensorflow.python.ops import control_flow_ops
#
# open __init__.py
#
# scroll down add
#
# from .load_backend import control_flow_ops
#
#
# then run !python train_yolo.py

# %%
# !python Train_YOLO.py
# Out:
# Using TensorFlow backend.
# 2020-05-06 14:46:34.453726: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-06 14:46:36.263820: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-06 14:46:36.286266: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-06 14:46:36.287008: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2020-05-06 14:46:36.287068: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 3_Inference/
# Out:
# /content/TrainYourOwnYOLO/3_Inference

# %% [markdown]
# again a error will come stating that cannot get session
#
# run the cell which is below detector.py
# !pip install keras==2.2.0
# !pip install tensorflow==1.14.0

# %% [markdown]
# Then again run the detector
#
# again a error stating that setup_modules not found
#
# run the cell below this detector.py
#
# !pip install keras_Applications==1.0.4

# %%
# !python Detector.py
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !pip install keras==2.2.0
# !pip install tensorflow==1.14.0
# Out:
# ...
#      |████████████████████████████████| 307kB 3.5MB/s
# ...
#      |████████████████████████████████| 51kB 6.0MB/s
# ERROR: tensorflow 2.2.0rc4 has requirement keras-preprocessing>=1.1.0, but you'll have keras-preprocessing 1.0.1 which is incompatible.
# ...
#   Found existing installation: Keras-Preprocessing 1.1.0
#     Uninstalling Keras-Preprocessing-1.1.0:
#       Successfully uninstalled Keras-Preprocessing-1.1.0
#   Found existing installation: Keras-Applications 1.0.8
#     Uninstalling Keras-Applications-1.0.8:
#       Successfully uninstalled Keras-Applications-1.0.8
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# ...
#      |████████████████████████████████| 109.2MB 38kB/s
# ...
#      |████████████████████████████████| 491kB 33.0MB/s
# ...
#      |████████████████████████████████| 51kB 6.5MB/s
# ...
#      |████████████████████████████████| 3.2MB 36.5MB/s
# ...
#      |████████████████████████████████| 51kB 6.7MB/s
# ...

# %%
# !pip install keras-Applications==1.0.4
# Out:
# ...
#      |████████████████████████████████| 51kB 1.9MB/s
# ...
#   Using cached https://files.pythonhosted.org/packages/f8/33/275506afe1d96b221f66f95adba94d1b73f6b6087cfb6132a5655b6fe338/Keras_Preprocessing-1.0.1-py2.py3-none-any.whl
# ...
# ERROR: tensorflow 1.14.0 has requirement keras-applications>=1.0.6, but you'll have keras-applications 1.0.4 which is incompatible.
# ERROR: tensorflow 1.14.0 has requirement keras-preprocessing>=1.0.5, but you'll have keras-preprocessing 1.0.1 which is incompatible.
# ERROR: keras 2.2.0 has requirement keras-applications==1.0.2, but you'll have keras-applications 1.0.4 which is incompatible.
# ...
#   Found existing installation: Keras-Applications 1.0.8
#     Uninstalling Keras-Applications-1.0.8:
#       Successfully uninstalled Keras-Applications-1.0.8
#   Found existing installation: Keras-Preprocessing 1.1.0
#     Uninstalling Keras-Preprocessing-1.1.0:
#       Successfully uninstalled Keras-Preprocessing-1.1.0
# ...
